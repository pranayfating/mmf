# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# %autoreload 2

# %%
import cv2
import numpy as np
from PIL import Image

from mmf.utils.visualize import visualize_frcnn_features

import utils

OBJ_URL = "https://raw.githubusercontent.com/airsplay/py-bottom-up-attention/master/demo/data/genome/1600-400-20/objects_vocab.txt"
ATTR_URL = "https://raw.githubusercontent.com/airsplay/py-bottom-up-attention/master/demo/data/genome/1600-400-20/attributes_vocab.txt"


if __name__ == "__main__":
    objids = utils.get_data(OBJ_URL)
    attrids = utils.get_data(ATTR_URL)
    names = ["first_image", "fourth_image"]
    image_path = "./example_images/second_image.jpg"
    features_path = "./output_features/second_image.npy"
    image_path1 = "./example_images/first_image.jpg"
    features_path1 = "./output_features/first_image.npy"
    
    for name in names:
        image_path = "./example_images/" + name + ".jpg"
        features_path = "./output_features/" + name + ".npy"
        visualize_frcnn_features(image_path, features_path, objids, attrids)
